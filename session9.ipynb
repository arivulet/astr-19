# %% [markdown]
# # Import matplotlib numpy and math

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Create array x with 1000 random steps distributed uniformly between 0,1

# %%
n = 1000

x = np.random.randn(n)

# %% [markdown]
# Def our main function that will make a plot

# %%
def main():
    #Create figure and axis
    fig, ax = plt.subplots(figsize=(10, 6))

    #create 100 bins
    width = 0.1
    histmin = 0
    histmax = 1

    #Add labels and title
    plt.xlabel('Randomness')
    plt.ylabel('Values per Bin')
    plt.title('Histogram of 1000 uniform random numbers')
    ax.grid(True)
    plt.hist(x,bins=100, alpha = 0.7, edgecolor='blue')

    #Save the figure as PDF
    plt.savefig('uniform_histogram.pdf', bbox_inches = "tight" , dpi=300)

    plt.show()

if __name__=="__main__":
    main()
